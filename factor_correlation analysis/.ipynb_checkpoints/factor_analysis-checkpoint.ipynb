# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import FactorAnalysis
from factor_analyzer import FactorAnalyzer, calculate_kmo
import os
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
# Set up file paths
os.chdir('/Users/nsusser/Desktop/Github/happyDB/')
# Load data 
input_path = 'data/filtered_ratings.csv'
reverse_coded_items_df = pd.read_csv('profiles/merged_reverse_coded_items_only.csv')
results = pd.read_csv(input_path)
print(reverse_coded_items_df.head())
# Out:
#   Scale                                  Dimension  \
# 0   CIT                         Autonomy - Control
# 1   CIT                         Autonomy - Control
# 2   CIT                         Autonomy - Control
# 3   CIT  Subjective Well-Being - Negative Feelings
# 4   CIT  Subjective Well-Being - Negative Feelings
#
#                                                Items
# 0  other people decided most of the speaker's lif...
# 1  the life choices the speaker made were not rea...
# 2  other people decided what the speaker could an...
# 3        the speaker felt negative most of the time?
# 4  the speaker experienced unhappy feelings most ...

# %%
# Clean and sanitize column names
reverse_coded_items_df['Scale'] = reverse_coded_items_df['Scale'].str.strip().str.replace(r"\s+", "_", regex=True)
reverse_coded_items_df['Dimension'] = reverse_coded_items_df['Dimension'].str.strip().str.replace(r"\s+", "_", regex=True)
reverse_coded_items_df['Items'] = reverse_coded_items_df['Items'].str.strip().str.replace(r"\s+", "_", regex=True)
print(reverse_coded_items_df.head())
# Out:
#   Scale                                  Dimension  \
# 0   CIT                         Autonomy_-_Control
# 1   CIT                         Autonomy_-_Control
# 2   CIT                         Autonomy_-_Control
# 3   CIT  Subjective_Well-Being_-_Negative_Feelings
# 4   CIT  Subjective_Well-Being_-_Negative_Feelings
#
#                                                Items
# 0  other_people_decided_most_of_the_speaker's_lif...
# 1  the_life_choices_the_speaker_made_were_not_rea...
# 2  other_people_decided_what_the_speaker_could_an...
# 3        the_speaker_felt_negative_most_of_the_time?
# 4  the_speaker_experienced_unhappy_feelings_most_...

# %%
# Create flattened column names
reversed_columns = [f"{scale}_{dimension}_{item}" for scale, dimension, item in zip(
    reverse_coded_items_df['Scale'], reverse_coded_items_df['Dimension'], reverse_coded_items_df['Items']
)]

# Get the maximum value in the dataset
max_value = 7  # Max value in the dataset

# Reverse coding based on the flattened column names
for col in reversed_columns:
    print(f"Reversing {col}")
    results[col] = max_value + 1 - results[col]
    print(f"Reversed {col}")

# Save the reversed dataset to csv
results.to_csv('data/reversed_ratings.csv', index=False)
# Out:
# Reversing CIT_Autonomy_-_Control_other_people_decided_most_of_the_speaker's_life_decisions?
# Reversed CIT_Autonomy_-_Control_other_people_decided_most_of_the_speaker's_life_decisions?
# Reversing CIT_Autonomy_-_Control_the_life_choices_the_speaker_made_were_not_really_theirs?
# Reversed CIT_Autonomy_-_Control_the_life_choices_the_speaker_made_were_not_really_theirs?
# Reversing CIT_Autonomy_-_Control_other_people_decided_what_the_speaker_could_and_could_not_do?
# Reversed CIT_Autonomy_-_Control_other_people_decided_what_the_speaker_could_and_could_not_do?
# Reversing CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_negative_most_of_the_time?
# Reversed CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_negative_most_of_the_time?
# Reversing CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_experienced_unhappy_feelings_most_of_the_time?
# Reversed CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_experienced_unhappy_feelings_most_of_the_time?
# Reversing CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_bad_most_of_the_time?
# Reversed CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_bad_most_of_the_time?
# Reversing PWB_Autonomy_the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?
# Reversed PWB_Autonomy_the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?
# Reversing PWB_Personal_Growth_the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?
# Reversed PWB_Personal_Growth_the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?
# Reversing PWB_Environmental_Mastery_the_speaker_felt_in_charge_of_the_situation?
# Reversed PWB_Environmental_Mastery_the_speaker_felt_in_charge_of_the_situation?
# Reversing PWB_Positive_Relations_the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?
# Reversed PWB_Positive_Relations_the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?
# Reversing PWB_Purpose_in_Life_the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?
# Reversed PWB_Purpose_in_Life_the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?
# Reversing PWB_Positive_Relations_the_speaker_was_seen_as_loving_and_affectionate?
# Reversed PWB_Positive_Relations_the_speaker_was_seen_as_loving_and_affectionate?
# Reversing PWB_Self-Acceptance_the_speaker_felt_pleased_with_how_their_life_had_turned_out?
# Reversed PWB_Self-Acceptance_the_speaker_felt_pleased_with_how_their_life_had_turned_out?
# Reversing PWB_Autonomy_the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?
# Reversed PWB_Autonomy_the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?
# Reversing PWB_Personal_Growth_the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?
# Reversed PWB_Personal_Growth_the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?
# Reversing PWB_Purpose_in_Life_the_speaker_felt_a_sense_of_direction_and_purpose?
# Reversed PWB_Purpose_in_Life_the_speaker_felt_a_sense_of_direction_and_purpose?
# Reversing PWB_Autonomy_the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?
# Reversed PWB_Autonomy_the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?
# Reversing PWB_Self-Acceptance_the_speaker_felt_confident_and_positive_about_themselves?
# Reversed PWB_Self-Acceptance_the_speaker_felt_confident_and_positive_about_themselves?
# Reversing PWB_Environmental_Mastery_the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?
# Reversed PWB_Environmental_Mastery_the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?
# Reversing PWB_Positive_Relations_the_speaker_felt_mutual_trust_with_their_friends?
# Reversed PWB_Positive_Relations_the_speaker_felt_mutual_trust_with_their_friends?
# Reversing PWB_Purpose_in_Life_the_speaker_felt_they_had_direction_in_life,_unlike_those_who_wander_aimlessly?
# Reversed PWB_Purpose_in_Life_the_speaker_felt_they_had_direction_in_life,_unlike_those_who_wander_aimlessly?
# Reversing PWB_Self-Acceptance_the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?
# Reversed PWB_Self-Acceptance_the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?
# Reversing PWB_Autonomy_the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?
# Reversed PWB_Autonomy_the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?
# Reversing PWB_Environmental_Mastery_the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?
# Reversed PWB_Environmental_Mastery_the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?
# Reversing PWB_Personal_Growth_the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?
# Reversed PWB_Personal_Growth_the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?
# Reversing PWB_Positive_Relations_the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?
# Reversed PWB_Positive_Relations_the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?
# Reversing PWB_Self-Acceptance_the_speaker_liked_most_parts_of_their_personality?
# Reversed PWB_Self-Acceptance_the_speaker_liked_most_parts_of_their_personality?

# %%
items_path = 'dataframes/scales_clean.csv'
items = pd.read_csv(items_path)

# Clean and sanitize column names
items['Scale'] = items['Scale'].str.strip().str.replace(r"\s+", "_", regex=True)
items['Dimension'] = items['Dimension'].str.strip().str.replace(r"\s+", "_", regex=True)
items['Items'] = items['Items'].str.strip().str.replace(r"\s+", "_", regex=True)

# Create flattened column names
cols = [f"{scale}_{dimension}_{item}" for scale, dimension, item in zip(
    items['Scale'], items['Dimension'], items['Items']
)]

# %%
#subset df with cols
df_subset = results[cols]
print(df_subset.columns)
# Out:
# Index(['PERMA_Accomplishment_the_speaker_felt_they_were_making_progress_towards_accomplishing_their_goals?',
#        'PERMA_Engagement_the_speaker_became_absorbed_in_what_they_were_doing?',
#        'PERMA_Positive_Emotion_the_speaker_felt_joyful?',
#        'PERMA_Negative_emotion_the_speaker_felt_anxious?',
#        'PERMA_Accomplishment_the_speaker_achieved_the_important_goals_they_set_for_themselves?',
#        'PERMA_Health_the_speaker_perceived_their_health_positively?',
#        'PERMA_Meaning_the_speaker_felt_their_life_was_purposeful_and_meaningful?',
#        'PERMA_Relationships_the_speaker_received_help_and_support_from_others_when_needed?',
#        'PERMA_Meaning_the_speaker_felt_what_they_did_in_life_was_valuable_and_worthwhile?',
#        'PERMA_Engagement_the_speaker_felt_excited_and_interested_in_things?',
#        ...
#        'CIT_Optimism_the_speaker_expected_more_good_things_in_their_life_than_bad?',
#        'CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_in_most_ways_their_life_was_close_to_their_ideal?',
#        'CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_satisfied_with_their_life?',
#        'CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_their_life_is_going_well?',
#        'CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_positive_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_happy_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_good_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_negative_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_experienced_unhappy_feelings_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_bad_most_of_the_time?'],
#       dtype='object', length=197)

# %%
#print(df_subset.head())
#standardize df_subset
scaler = StandardScaler()
df_subset = pd.DataFrame(scaler.fit_transform(df_subset), columns=df_subset.columns)

#calculate kmo and bartlett's test
kmo_all, kmo_model = calculate_kmo(df_subset)

#determine optimal number of factors
fa = FactorAnalyzer(rotation=None)
fa.fit(df_subset)
eigenvalues, _ = fa.get_eigenvalues()

#fit factor analysis with optimal factors
optimal_factors = sum(eigenvalues > 1) # or based on scree plot
fa = FactorAnalyzer(n_factors=optimal_factors, rotation='varimax')
fa.fit(df_subset)

#project cols onto factors
factor_scores = fa.transform(df_subset)
for i in range(factor_scores.shape[1]):
    results[f'Factor_{i+1}'] = factor_scores[:, i]
# Out:
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/factor_analyzer/utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Plot Scree Plot
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, marker='o', linestyle='--')
plt.xlabel('Number of Factors')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot')
plt.axhline(y=1, color='r', linestyle='--', label="Eigenvalue = 1 Threshold")
plt.legend()
plt.grid()
plt.show()

# %%
#save csv
results.to_csv('analysis_data/results - factors.csv')

# %%
#print top ten
variable_name_mapping = dict(zip(cols, items)) #map cols to variable names
factor_loadings = pd.DataFrame(fa.loadings_, index=items)


for i in range(factor_loadings.shape[1]):
    sorted_loadings = factor_loadings.iloc[:, i].abs().sort_values(ascending=False)
    top_variables = sorted_loadings.head(10).index.tolist()
    print(f'Factor {i+1}: {top_variables}')


# Create an empty list to store the results
factor_loading_results = []

# Iterate through each factor's loadings
for i in range(factor_loadings.shape[1]):
    sorted_loadings = factor_loadings.iloc[:, i].abs().sort_values(ascending=False)
    top_variables = sorted_loadings.head(10).index.tolist()
    top_loadings = sorted_loadings.head(10).values.tolist()
    
    # Append each factor's results to the list
    for var, loading in zip(top_variables, top_loadings):
        factor_loading_results.append({
            'Factor': f'Factor {i+1}',
            'Variable': var,
            'Loading': loading
        })

# Convert the results to a DataFrame
factor_loading_df = pd.DataFrame(factor_loading_results)

# Save to a CSV file
factor_loading_df.to_csv('factor_loadings.csv', index=False)

print("Factor loadings saved to 'factor_loadings.csv'.")
# Out:
# Factor 1: [('PERMA', 'Positive_Emotion', 'the_speaker_felt_joyful?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_happy?'), ('WBP', 'Optimism', 'the_speaker_felt_very_optimistic_in_the_moment?'), ('WBP', 'Positive_Emotions', 'the_speaker_considered_themselves_happy?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_cheerful?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_cheerful_and_in_good_spirits?'), ('PERMA', 'Happiness', 'the_speaker_felt_happy_overall?'), ('PANAS', 'Positive', 'the_speaker_was_enthusiastic?'), ('PERMA', 'Positive_Emotion', 'the_speaker_felt_contented?'), ('PERMA', 'Positive_Emotion', 'the_speaker_felt_positive?')]
# Factor 2: [('WBP', 'Competence', 'the_speaker_was_competent_and_capable_in_important_activities?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_succeeded_when_they_put_their_mind_to_it?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_believed_that_they_are_capable_in_most_things?'), ('WBP', 'Meaning', 'the_speaker_felt_a_sense_of_direction?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_a_sense_of_direction_and_purpose?'), ('WBP', 'Meaning', 'the_speaker_had_a_clear_sense_of_purpose?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_skills_a_lot_in_their_everyday_life?'), ('PANAS', 'Positive', 'the_speaker_was_determined?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_talents?'), ('PERMA', 'Meaning', 'the_speaker_felt_they_had_a_sense_of_direction_in_life?')]
# Factor 3: [('PWB', 'Environmental_Mastery', 'the_demands_of_everyday_life_affected_the_speaker_negatively?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_experienced_unhappy_feelings_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?'), ('PANAS', 'Negative', 'the_speaker_was_upset?'), ('PWB', 'Environmental_Mastery', 'the_speaker_found_it_difficult_to_arrange_their_life_in_a_satisfying_way?'), ('PWB', 'Self-Acceptance', "the_speaker's_self-attitude_was_less_positive_than_most_people's?"), ('WBP', 'Self-Acceptance', 'the_speaker_admitted_their_shortcomings_without_shame_or_embarrassment?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_anxious?')]
# Factor 4: [('WBP', 'Positive_Relationships', 'the_speaker_felt_supported_by_people_who_care_about_them?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_appreciated_the_speaker_as_a_person?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?'), ('PERMA', 'Relationships', 'the_speaker_felt_satisfied_with_their_personal_relationships?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('PERMA', 'Relationships', 'the_speaker_felt_loved?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_people_with_whom_they_can_discuss_intimate_and_personal_matters?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('PWB', 'Positive_Relations', 'the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?'), ('CIT', 'Relationship_-_Trust', 'the_speaker_trusted_people_in_their_society?')]
# Factor 5: [('CIT', 'Relationship_-_Community', 'the_speaker_pitched_in_to_help_when_their_local_community_needed_something_done?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_offered_help_to_others?'), ('CIT', 'Relationship_-_Community', 'the_speaker_looked_for_ways_to_help_their_neighbors_when_they_are_in_need?'), ('WBP', 'Empathy', "the_speaker's_heart_went_out_to_people_who_are_unhappy?"), ('WBP', 'Prosocial_Behavior', 'the_speaker_willingly_gave_their_time_to_others_in_need?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_would_do_almost_anything_they_could_to_assist_if_a_person_needed_help?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_things_they_did_contributed_to_society?'), ('WBP', 'Empathy', "other_people's_misfortunes_disturbed_the_speaker_a_great_deal?"), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_work_they_did_was_important_for_other_people?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?')]
# Factor 6: [('PERMA', 'Engagement', 'the_speaker_became_absorbed_in_what_they_were_doing?'), ('CIT', 'Engagement', 'the_speaker_was_fully_absorbed_in_the_activities_they_were_doing?'), ('PERMA', 'Engagement', 'the_speaker_lost_track_of_time_while_doing_something_they_enjoyed?'), ('WHO-5', 'Well-Being', "the_speaker's_daily_life_has_been_filled_with_things_that_interest_them?"), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PWB', 'Purpose_in_Life', 'the_speaker_lived_one_day_at_a_time_without_much_thought_for_the_future?'), ('WBP', 'Engagement', 'the_speaker_was_engaged_and_interested_in_the_activity?'), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('PANAS', 'Positive', 'the_speaker_was_interested?')]
# Factor 7: [('PERMA', 'Health', 'the_speaker_felt_satisfied_with_their_current_physical_health?'), ('PERMA', 'Health', 'the_speaker_perceived_their_health_to_be_better_than_others_of_the_same_age_and_sex?'), ('PERMA', 'Health', 'the_speaker_perceived_their_health_positively?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?')]
# Factor 8: [('WBP', 'Autonomy', 'the_speaker_felt_free_to_make_their_own_choices?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_act_on_their_decisions?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_in_charge_of_the_situation?'), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('PWB', 'Autonomy', "the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?"), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?')]
# Factor 9: [('WHO-5', 'Well-Being', 'the_speaker_felt_active_and_vigorous?'), ('WBP', 'Vitality', 'the_speaker_felt_active_and_vigorous?'), ('WBP', 'Vitality', 'the_speaker_felt_energetic?'), ('WBP', 'Vitality', 'the_speaker_felt_full_of_energy?'), ('CIT', 'Engagement', 'the_speaker_felt_energized_in_most_activities_they_do?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('WBP', 'Engagement', 'the_speaker_felt_excited_by_what_they_were_doing?'), ('PERMA', 'Engagement', 'the_speaker_felt_excited_and_interested_in_things?'), ('PANAS', 'Positive', 'the_speaker_was_excited?')]
# Factor 10: [('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_state_or_province?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('CIT', 'Relationship_-_Community', 'the_speaker_invited_their_neighbors_to_their_home?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_community?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?')]
# Factor 11: [('CIT', 'Mastery_-_Learning', 'the_speaker_learned_something_new?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_always_learns_something_everyday?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_felt_learning_new_things_is_important?'), ('PWB', 'Personal_Growth', 'the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?'), ('PWB', 'Personal_Growth', 'the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?'), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('PWB', 'Personal_Growth', 'the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('PANAS', 'Positive', 'the_speaker_was_inspired?')]
# Factor 12: [('PANAS', 'Negative', 'the_speaker_was_nervous?'), ('PANAS', 'Negative', 'the_speaker_was_scared?'), ('PANAS', 'Negative', 'the_speaker_was_afraid?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_anxious?'), ('PANAS', 'Negative', 'the_speaker_was_jittery?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_was_confident_that_they_could_deal_with_unexpected_events?')]
# Factor 13: [('WBP', 'Emotional_Stability', 'the_speaker_maintained_their_composure?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('WBP', 'Emotional_Stability', 'the_speaker_was_emotionally_balanced_and_even-tempered?'), ('WBP', 'Emotional_Stability', 'the_speaker_did_not_get_upset_easily?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('WBP', 'Clear_Thinking', 'the_speaker’s_ability_to_think_clearly?'), ('PERMA', 'Accomplishment', 'the_speaker_was_able_to_handle_their_responsibilities?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_was_confident_that_they_could_deal_with_unexpected_events?')]
# Factor 14: [('CIT', 'Relationship_-_Loneliness', 'the_speaker_felt_lonely?'), ('PERMA', 'Lonliness', 'the_speaker_felt_lonely_in_their_daily_life?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_lonely_due_to_a_lack_of_close_friends_for_sharing_concerns?'), ('CIT', 'Relationship_-_Loneliness', 'the_speaker_often_felt_left_out?'), ('PWB', 'Positive_Relations', 'the_speaker_found_it_difficult_and_frustrating_to_maintain_close_relationships?'), ('CIT', 'Relationship_-_Loneliness', 'there_was_no_one_the_speaker_felt_close_to?'), ('PWB', 'Positive_Relations', 'the_speaker_had_not_experienced_many_warm_and_trusting_relationships_with_others?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_they_did_not_fit_well_with_the_people_and_community_around_them?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_others_had_gotten_more_out_of_life_than_they_had?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?")]
# Factor 15: [('WBP', 'Positive_Relationships', 'the_speaker_received_help_and_support_from_others_when_they_needed_it?'), ('PERMA', 'Relationships', 'the_speaker_received_help_and_support_from_others_when_needed?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('PWB', 'Positive_Relations', 'the_speaker_was_seen_as_loving_and_affectionate?'), ('WBP', 'Empathy', "the_speaker_felt_other's_emotions?"), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?'), ('CIT', 'Meaning', 'the_speaker_felt_their_life_has_a_clear_sense_of_purpose?'), ('PERMA', 'Relationships', 'the_speaker_felt_satisfied_with_their_personal_relationships?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?')]
# Factor 16: [('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PANAS', 'Positive', 'the_speaker_was_interested?'), ('WBP', 'Engagement', 'the_speaker_was_engaged_and_interested_in_the_activity?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('CIT', 'Autonomy_-_Control', 'the_life_choices_the_speaker_made_were_not_really_theirs?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?')]
# Factor 17: [('SWLS', 'LS', 'the_speaker_felt_they_had_gotten_the_important_things_they_wanted_in_life?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_in_most_ways_their_life_was_close_to_their_ideal?'), ('SWLS', 'LS', 'the_speaker_felt_their_life_was_close_to_their_ideal?'), ('CIT', 'Meaning', 'the_speaker_felt_they_had_found_a_satisfactory_meaning_in_life?'), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?'), ('PERMA', 'Meaning', 'the_speaker_felt_what_they_did_in_life_was_valuable_and_worthwhile?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_pleased_with_how_their_life_had_turned_out?'), ('SWLS', 'LS', 'the_speaker_felt_the_conditions_of_their_life_were_excellent?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_what_they_do_in_life_is_valuable_and_worthwhile?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?')]
# Factor 18: [('CIT', 'Relationship_-_Respect', 'people_respected_the_speaker?'), ('CIT', 'Relationship_-_Respect', 'people_were_polite_to_the_speaker?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?'), ('PWB', 'Positive_Relations', 'the_speaker_was_seen_as_loving_and_affectionate?'), ('CIT', 'Relationship_-_Respect', 'the_speaker_was_treated_with_the_same_amount_of_respect_as_others?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('WBP', 'Competence', 'the_speaker_believes_they_do_most_things_well?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?')]
# Factor 19: [('PANAS', 'Negative', 'the_speaker_was_hostile?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_angry?'), ('PANAS', 'Negative', 'the_speaker_was_irritable?'), ('PANAS', 'Negative', 'the_speaker_was_upset?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('WBP', 'Self-Acceptance', 'the_speaker_saw_their_own_problems_and_shortcomings_without_getting_distressed_by_them?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('WBP', 'Self-Acceptance', 'the_speaker_accepted_their_flaws_and_inadequacies?'), ('PWB', 'Personal_Growth', "the_speaker_felt_they_hadn't_improved_much_as_a_person_over_the_years?"), ('WBP', 'Empathy', "other_people's_misfortunes_disturbed_the_speaker_a_great_deal?")]
# Factor 20: [('PANAS', 'Positive', 'the_speaker_was_inspired?'), ('WBP', 'Optimism', 'the_speaker_always_feels_optimistic_in_the_moment?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_talents?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_skills_a_lot_in_their_everyday_life?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('CIT', 'Optimism', 'the_speaker_felt_optimistic_about_their_future?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_felt_they_do_what_they_are_good_at_everyday?'), ('PWB', 'Autonomy', 'the_speaker_found_it_difficult_to_voice_their_opinions_on_controversial_matters?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?'), ('WBP', 'Engagement', 'the_speaker_felt_excited_by_what_they_were_doing?')]
# Factor 21: [('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?'), ('PANAS', 'Positive', 'the_speaker_was_proud?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_state_or_province?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('CIT', 'Engagement', 'the_speaker_felt_excited_when_they_were_working_on_something?')]
# Factor loadings saved to 'factor_loadings.csv'.

# %%
# Dictionary to store items by factors
factor_items = {}

# Iterate through each factor's loadings
for i in range(factor_loadings.shape[1]):
    sorted_loadings = factor_loadings.iloc[:, i].abs().sort_values(ascending=False)
    top_variables = sorted_loadings.index.tolist()  # Get all variables sorted by absolute loading
    
    # Add variables to the factor_items dictionary
    factor_items[f'Factor {i+1}'] = top_variables

    # Print top 10 variables for the current factor
    top_ten = top_variables[:10]
    print(f'Factor {i+1}: {top_ten}')

# Convert the results to a DataFrame for export (optional)
factor_loading_results = [
    {
        'Factor': factor, 
        'Variables': ', '.join([str(variable) for variable in variables])  # Convert tuples to strings
    }
    for factor, variables in factor_items.items()
]

# Convert to DataFrame and save to CSV
factor_loading_df = pd.DataFrame(factor_loading_results)
factor_loading_df.to_csv('factor_loadings_grouped.csv', index=False)

print("Factor loadings grouped by factor saved to 'factor_loadings_grouped.csv'.")

# Save the factor_items dictionary for visualization (optional)
with open('factor_items.json', 'w') as f:
    import json
    json.dump(factor_items, f)

print("Factor items saved to 'factor_items.json'.")
# Out:
# Factor 1: [('PERMA', 'Positive_Emotion', 'the_speaker_felt_joyful?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_happy?'), ('WBP', 'Optimism', 'the_speaker_felt_very_optimistic_in_the_moment?'), ('WBP', 'Positive_Emotions', 'the_speaker_considered_themselves_happy?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_cheerful?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_cheerful_and_in_good_spirits?'), ('PERMA', 'Happiness', 'the_speaker_felt_happy_overall?'), ('PANAS', 'Positive', 'the_speaker_was_enthusiastic?'), ('PERMA', 'Positive_Emotion', 'the_speaker_felt_contented?'), ('PERMA', 'Positive_Emotion', 'the_speaker_felt_positive?')]
# Factor 2: [('WBP', 'Competence', 'the_speaker_was_competent_and_capable_in_important_activities?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_succeeded_when_they_put_their_mind_to_it?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_believed_that_they_are_capable_in_most_things?'), ('WBP', 'Meaning', 'the_speaker_felt_a_sense_of_direction?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_a_sense_of_direction_and_purpose?'), ('WBP', 'Meaning', 'the_speaker_had_a_clear_sense_of_purpose?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_skills_a_lot_in_their_everyday_life?'), ('PANAS', 'Positive', 'the_speaker_was_determined?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_talents?'), ('PERMA', 'Meaning', 'the_speaker_felt_they_had_a_sense_of_direction_in_life?')]
# Factor 3: [('PWB', 'Environmental_Mastery', 'the_demands_of_everyday_life_affected_the_speaker_negatively?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_experienced_unhappy_feelings_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?'), ('PANAS', 'Negative', 'the_speaker_was_upset?'), ('PWB', 'Environmental_Mastery', 'the_speaker_found_it_difficult_to_arrange_their_life_in_a_satisfying_way?'), ('PWB', 'Self-Acceptance', "the_speaker's_self-attitude_was_less_positive_than_most_people's?"), ('WBP', 'Self-Acceptance', 'the_speaker_admitted_their_shortcomings_without_shame_or_embarrassment?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_anxious?')]
# Factor 4: [('WBP', 'Positive_Relationships', 'the_speaker_felt_supported_by_people_who_care_about_them?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_appreciated_the_speaker_as_a_person?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?'), ('PERMA', 'Relationships', 'the_speaker_felt_satisfied_with_their_personal_relationships?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('PERMA', 'Relationships', 'the_speaker_felt_loved?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_people_with_whom_they_can_discuss_intimate_and_personal_matters?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('PWB', 'Positive_Relations', 'the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?'), ('CIT', 'Relationship_-_Trust', 'the_speaker_trusted_people_in_their_society?')]
# Factor 5: [('CIT', 'Relationship_-_Community', 'the_speaker_pitched_in_to_help_when_their_local_community_needed_something_done?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_offered_help_to_others?'), ('CIT', 'Relationship_-_Community', 'the_speaker_looked_for_ways_to_help_their_neighbors_when_they_are_in_need?'), ('WBP', 'Empathy', "the_speaker's_heart_went_out_to_people_who_are_unhappy?"), ('WBP', 'Prosocial_Behavior', 'the_speaker_willingly_gave_their_time_to_others_in_need?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_would_do_almost_anything_they_could_to_assist_if_a_person_needed_help?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_things_they_did_contributed_to_society?'), ('WBP', 'Empathy', "other_people's_misfortunes_disturbed_the_speaker_a_great_deal?"), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_work_they_did_was_important_for_other_people?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?')]
# Factor 6: [('PERMA', 'Engagement', 'the_speaker_became_absorbed_in_what_they_were_doing?'), ('CIT', 'Engagement', 'the_speaker_was_fully_absorbed_in_the_activities_they_were_doing?'), ('PERMA', 'Engagement', 'the_speaker_lost_track_of_time_while_doing_something_they_enjoyed?'), ('WHO-5', 'Well-Being', "the_speaker's_daily_life_has_been_filled_with_things_that_interest_them?"), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PWB', 'Purpose_in_Life', 'the_speaker_lived_one_day_at_a_time_without_much_thought_for_the_future?'), ('WBP', 'Engagement', 'the_speaker_was_engaged_and_interested_in_the_activity?'), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('PANAS', 'Positive', 'the_speaker_was_interested?')]
# Factor 7: [('PERMA', 'Health', 'the_speaker_felt_satisfied_with_their_current_physical_health?'), ('PERMA', 'Health', 'the_speaker_perceived_their_health_to_be_better_than_others_of_the_same_age_and_sex?'), ('PERMA', 'Health', 'the_speaker_perceived_their_health_positively?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?')]
# Factor 8: [('WBP', 'Autonomy', 'the_speaker_felt_free_to_make_their_own_choices?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_act_on_their_decisions?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_in_charge_of_the_situation?'), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('PWB', 'Autonomy', "the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?"), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?')]
# Factor 9: [('WHO-5', 'Well-Being', 'the_speaker_felt_active_and_vigorous?'), ('WBP', 'Vitality', 'the_speaker_felt_active_and_vigorous?'), ('WBP', 'Vitality', 'the_speaker_felt_energetic?'), ('WBP', 'Vitality', 'the_speaker_felt_full_of_energy?'), ('CIT', 'Engagement', 'the_speaker_felt_energized_in_most_activities_they_do?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('WBP', 'Engagement', 'the_speaker_felt_excited_by_what_they_were_doing?'), ('PERMA', 'Engagement', 'the_speaker_felt_excited_and_interested_in_things?'), ('PANAS', 'Positive', 'the_speaker_was_excited?')]
# Factor 10: [('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_state_or_province?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('CIT', 'Relationship_-_Community', 'the_speaker_invited_their_neighbors_to_their_home?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_community?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?')]
# Factor 11: [('CIT', 'Mastery_-_Learning', 'the_speaker_learned_something_new?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_always_learns_something_everyday?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_felt_learning_new_things_is_important?'), ('PWB', 'Personal_Growth', 'the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?'), ('PWB', 'Personal_Growth', 'the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?'), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('PWB', 'Personal_Growth', 'the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('PANAS', 'Positive', 'the_speaker_was_inspired?')]
# Factor 12: [('PANAS', 'Negative', 'the_speaker_was_nervous?'), ('PANAS', 'Negative', 'the_speaker_was_scared?'), ('PANAS', 'Negative', 'the_speaker_was_afraid?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_anxious?'), ('PANAS', 'Negative', 'the_speaker_was_jittery?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_was_confident_that_they_could_deal_with_unexpected_events?')]
# Factor 13: [('WBP', 'Emotional_Stability', 'the_speaker_maintained_their_composure?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('WBP', 'Emotional_Stability', 'the_speaker_was_emotionally_balanced_and_even-tempered?'), ('WBP', 'Emotional_Stability', 'the_speaker_did_not_get_upset_easily?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('WBP', 'Clear_Thinking', 'the_speaker’s_ability_to_think_clearly?'), ('PERMA', 'Accomplishment', 'the_speaker_was_able_to_handle_their_responsibilities?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_was_confident_that_they_could_deal_with_unexpected_events?')]
# Factor 14: [('CIT', 'Relationship_-_Loneliness', 'the_speaker_felt_lonely?'), ('PERMA', 'Lonliness', 'the_speaker_felt_lonely_in_their_daily_life?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_lonely_due_to_a_lack_of_close_friends_for_sharing_concerns?'), ('CIT', 'Relationship_-_Loneliness', 'the_speaker_often_felt_left_out?'), ('PWB', 'Positive_Relations', 'the_speaker_found_it_difficult_and_frustrating_to_maintain_close_relationships?'), ('CIT', 'Relationship_-_Loneliness', 'there_was_no_one_the_speaker_felt_close_to?'), ('PWB', 'Positive_Relations', 'the_speaker_had_not_experienced_many_warm_and_trusting_relationships_with_others?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_they_did_not_fit_well_with_the_people_and_community_around_them?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_others_had_gotten_more_out_of_life_than_they_had?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?")]
# Factor 15: [('WBP', 'Positive_Relationships', 'the_speaker_received_help_and_support_from_others_when_they_needed_it?'), ('PERMA', 'Relationships', 'the_speaker_received_help_and_support_from_others_when_needed?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('PWB', 'Positive_Relations', 'the_speaker_was_seen_as_loving_and_affectionate?'), ('WBP', 'Empathy', "the_speaker_felt_other's_emotions?"), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?'), ('CIT', 'Meaning', 'the_speaker_felt_their_life_has_a_clear_sense_of_purpose?'), ('PERMA', 'Relationships', 'the_speaker_felt_satisfied_with_their_personal_relationships?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?')]
# Factor 16: [('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PANAS', 'Positive', 'the_speaker_was_interested?'), ('WBP', 'Engagement', 'the_speaker_was_engaged_and_interested_in_the_activity?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('CIT', 'Autonomy_-_Control', 'the_life_choices_the_speaker_made_were_not_really_theirs?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?')]
# Factor 17: [('SWLS', 'LS', 'the_speaker_felt_they_had_gotten_the_important_things_they_wanted_in_life?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_in_most_ways_their_life_was_close_to_their_ideal?'), ('SWLS', 'LS', 'the_speaker_felt_their_life_was_close_to_their_ideal?'), ('CIT', 'Meaning', 'the_speaker_felt_they_had_found_a_satisfactory_meaning_in_life?'), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?'), ('PERMA', 'Meaning', 'the_speaker_felt_what_they_did_in_life_was_valuable_and_worthwhile?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_pleased_with_how_their_life_had_turned_out?'), ('SWLS', 'LS', 'the_speaker_felt_the_conditions_of_their_life_were_excellent?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_what_they_do_in_life_is_valuable_and_worthwhile?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?')]
# Factor 18: [('CIT', 'Relationship_-_Respect', 'people_respected_the_speaker?'), ('CIT', 'Relationship_-_Respect', 'people_were_polite_to_the_speaker?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?'), ('PWB', 'Positive_Relations', 'the_speaker_was_seen_as_loving_and_affectionate?'), ('CIT', 'Relationship_-_Respect', 'the_speaker_was_treated_with_the_same_amount_of_respect_as_others?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('WBP', 'Competence', 'the_speaker_believes_they_do_most_things_well?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?')]
# Factor 19: [('PANAS', 'Negative', 'the_speaker_was_hostile?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_angry?'), ('PANAS', 'Negative', 'the_speaker_was_irritable?'), ('PANAS', 'Negative', 'the_speaker_was_upset?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('WBP', 'Self-Acceptance', 'the_speaker_saw_their_own_problems_and_shortcomings_without_getting_distressed_by_them?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('WBP', 'Self-Acceptance', 'the_speaker_accepted_their_flaws_and_inadequacies?'), ('PWB', 'Personal_Growth', "the_speaker_felt_they_hadn't_improved_much_as_a_person_over_the_years?"), ('WBP', 'Empathy', "other_people's_misfortunes_disturbed_the_speaker_a_great_deal?")]
# Factor 20: [('PANAS', 'Positive', 'the_speaker_was_inspired?'), ('WBP', 'Optimism', 'the_speaker_always_feels_optimistic_in_the_moment?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_talents?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_skills_a_lot_in_their_everyday_life?'), ('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('CIT', 'Optimism', 'the_speaker_felt_optimistic_about_their_future?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_felt_they_do_what_they_are_good_at_everyday?'), ('PWB', 'Autonomy', 'the_speaker_found_it_difficult_to_voice_their_opinions_on_controversial_matters?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?'), ('WBP', 'Engagement', 'the_speaker_felt_excited_by_what_they_were_doing?')]
# Factor 21: [('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?'), ('PANAS', 'Positive', 'the_speaker_was_proud?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_state_or_province?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('CIT', 'Engagement', 'the_speaker_felt_excited_when_they_were_working_on_something?')]
# Factor loadings grouped by factor saved to 'factor_loadings_grouped.csv'.
# Factor items saved to 'factor_items.json'.

# %%
# Apply PCA
pca = PCA()
principal_components = pca.fit_transform(df_subset)

# Explained variance ratio
explained_variance = pca.explained_variance_ratio_

# Scree Plot for PCA
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o', linestyle='--')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.title('Scree Plot for PCA')
plt.axhline(y=0.1, color='r', linestyle='--', label="Threshold")
plt.legend()
plt.grid()
plt.show()

# Select number of components (retain 95% variance)
cumulative_variance = np.cumsum(explained_variance)
optimal_components = np.argmax(cumulative_variance >= 0.95) + 1  # Keep 95% variance

print(f"Optimal number of components: {optimal_components}")

# Fit PCA with the optimal number of components
pca_optimal = PCA(n_components=optimal_components)
principal_components_optimal = pca_optimal.fit_transform(df_subset)

# Convert to DataFrame
df_pca = pd.DataFrame(principal_components_optimal, columns=[f'PC{i+1}' for i in range(optimal_components)])

# Display the transformed dataset
print(df_pca.head())  # Print first few rows of the transformed dataset
# Out:
# Optimal number of components: 130
#         PC1        PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  6.751848   2.027238  2.495983 -0.883385  1.186183 -0.154432  1.329427
# 1  1.624627  -5.255479  0.024384  2.877595 -4.984636 -2.746157  4.158150
# 2 -1.556567   0.720282 -5.124594 -4.019368  2.604855 -1.277302 -1.086072
# 3  5.228632  12.409686  6.217328 -0.545880  0.527783  0.895594 -0.104613
# 4  2.900350  -4.813176  2.081569 -1.891722  1.595124 -0.423591  1.348880
#
#         PC8       PC9      PC10  ...     PC121     PC122     PC123     PC124  \
# 0  0.668484 -0.559268  0.293163  ... -0.542191  0.210176  0.306105  0.009283
# 1 -1.248740 -0.636629  0.053742  ...  0.416656  0.246368  0.097564  0.263981
# 2 -1.274131  0.205719 -1.271343  ...  0.928959  0.147405  0.205035  0.109647
# 3  3.669403  1.457090  3.851642  ...  0.032987  0.017120  0.176199 -0.109918
# 4 -2.088412  1.520838 -1.260126  ...  0.398605 -0.266612  0.612442 -0.280268
#
#       PC125     PC126     PC127     PC128     PC129     PC130
# 0 -0.367700 -0.619420  0.079131 -0.685196 -0.425885  0.215016
# 1  0.258356  0.079802 -0.052529  0.120170 -0.404188 -1.049684
# 2  0.687436  0.678653  1.067470 -0.293399 -0.450063  0.232794
# 3  0.244739  0.623722  0.447623 -0.151858 -0.321265  0.281049
# 4  0.202289  0.718428  0.134136  0.453424 -0.521481  0.318438
#
# [5 rows x 130 columns]
