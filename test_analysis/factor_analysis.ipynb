# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import FactorAnalysis
from factor_analyzer import FactorAnalyzer, calculate_kmo
import os
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Set up file paths
os.chdir('/Users/nsusser/Desktop/Github/happyDB/')
# Load data 
input_path = 'dataframes/tests/gpt40-mini/merged_data_1000.csv'
reverse_coded_items_df = pd.read_csv('profiles/merged_reverse_coded_items_only.csv')
results = pd.read_csv(input_path, nrows=1000)
print(reverse_coded_items_df.head())
# Out:
#   Scale                                  Dimension  \
# 0   CIT                         Autonomy - Control
# 1   CIT                         Autonomy - Control
# 2   CIT                         Autonomy - Control
# 3   CIT  Subjective Well-Being - Negative Feelings
# 4   CIT  Subjective Well-Being - Negative Feelings
#
#                                                Items
# 0  other people decided most of the speaker's lif...
# 1  the life choices the speaker made were not rea...
# 2  other people decided what the speaker could an...
# 3        the speaker felt negative most of the time?
# 4  the speaker experienced unhappy feelings most ...

# %%
# Clean and sanitize column names
reverse_coded_items_df['Scale'] = reverse_coded_items_df['Scale'].str.strip().str.replace(r"\s+", "_", regex=True)
reverse_coded_items_df['Dimension'] = reverse_coded_items_df['Dimension'].str.strip().str.replace(r"\s+", "_", regex=True)
reverse_coded_items_df['Items'] = reverse_coded_items_df['Items'].str.strip().str.replace(r"\s+", "_", regex=True)
print(reverse_coded_items_df.head())
# Out:
#   Scale                                  Dimension  \
# 0   CIT                         Autonomy_-_Control
# 1   CIT                         Autonomy_-_Control
# 2   CIT                         Autonomy_-_Control
# 3   CIT  Subjective_Well-Being_-_Negative_Feelings
# 4   CIT  Subjective_Well-Being_-_Negative_Feelings
#
#                                                Items
# 0  other_people_decided_most_of_the_speaker's_lif...
# 1  the_life_choices_the_speaker_made_were_not_rea...
# 2  other_people_decided_what_the_speaker_could_an...
# 3        the_speaker_felt_negative_most_of_the_time?
# 4  the_speaker_experienced_unhappy_feelings_most_...

# %%
# Create flattened column names
reversed_columns = [f"{scale}_{dimension}_{item}" for scale, dimension, item in zip(
    reverse_coded_items_df['Scale'], reverse_coded_items_df['Dimension'], reverse_coded_items_df['Items']
)]

# Get the maximum value in the dataset
max_value = 7  # Max value in the dataset

# Reverse coding based on the flattened column names
for col in reversed_columns:
    print(f"Reversing {col}")
    results[col] = max_value + 1 - results[col]
    print(f"Reversed {col}")
# Out:
# Reversing CIT_Autonomy_-_Control_other_people_decided_most_of_the_speaker's_life_decisions?
# Reversed CIT_Autonomy_-_Control_other_people_decided_most_of_the_speaker's_life_decisions?
# Reversing CIT_Autonomy_-_Control_the_life_choices_the_speaker_made_were_not_really_theirs?
# Reversed CIT_Autonomy_-_Control_the_life_choices_the_speaker_made_were_not_really_theirs?
# Reversing CIT_Autonomy_-_Control_other_people_decided_what_the_speaker_could_and_could_not_do?
# Reversed CIT_Autonomy_-_Control_other_people_decided_what_the_speaker_could_and_could_not_do?
# Reversing CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_negative_most_of_the_time?
# Reversed CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_negative_most_of_the_time?
# Reversing CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_experienced_unhappy_feelings_most_of_the_time?
# Reversed CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_experienced_unhappy_feelings_most_of_the_time?
# Reversing CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_bad_most_of_the_time?
# Reversed CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_bad_most_of_the_time?
# Reversing PWB_Autonomy_the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?
# Reversed PWB_Autonomy_the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?
# Reversing PWB_Personal_Growth_the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?
# Reversed PWB_Personal_Growth_the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?
# Reversing PWB_Environmental_Mastery_the_speaker_felt_in_charge_of_the_situation?
# Reversed PWB_Environmental_Mastery_the_speaker_felt_in_charge_of_the_situation?
# Reversing PWB_Positive_Relations_the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?
# Reversed PWB_Positive_Relations_the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?
# Reversing PWB_Purpose_in_Life_the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?
# Reversed PWB_Purpose_in_Life_the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?
# Reversing PWB_Positive_Relations_the_speaker_was_seen_as_loving_and_affectionate?
# Reversed PWB_Positive_Relations_the_speaker_was_seen_as_loving_and_affectionate?
# Reversing PWB_Self-Acceptance_the_speaker_felt_pleased_with_how_their_life_had_turned_out?
# Reversed PWB_Self-Acceptance_the_speaker_felt_pleased_with_how_their_life_had_turned_out?
# Reversing PWB_Autonomy_the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?
# Reversed PWB_Autonomy_the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?
# Reversing PWB_Personal_Growth_the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?
# Reversed PWB_Personal_Growth_the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?
# Reversing PWB_Purpose_in_Life_the_speaker_felt_a_sense_of_direction_and_purpose?
# Reversed PWB_Purpose_in_Life_the_speaker_felt_a_sense_of_direction_and_purpose?
# Reversing PWB_Autonomy_the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?
# Reversed PWB_Autonomy_the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?
# Reversing PWB_Self-Acceptance_the_speaker_felt_confident_and_positive_about_themselves?
# Reversed PWB_Self-Acceptance_the_speaker_felt_confident_and_positive_about_themselves?
# Reversing PWB_Environmental_Mastery_the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?
# Reversed PWB_Environmental_Mastery_the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?
# Reversing PWB_Positive_Relations_the_speaker_felt_mutual_trust_with_their_friends?
# Reversed PWB_Positive_Relations_the_speaker_felt_mutual_trust_with_their_friends?
# Reversing PWB_Purpose_in_Life_the_speaker_felt_they_had_direction_in_life,_unlike_those_who_wander_aimlessly?
# Reversed PWB_Purpose_in_Life_the_speaker_felt_they_had_direction_in_life,_unlike_those_who_wander_aimlessly?
# Reversing PWB_Self-Acceptance_the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?
# Reversed PWB_Self-Acceptance_the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?
# Reversing PWB_Autonomy_the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?
# Reversed PWB_Autonomy_the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?
# Reversing PWB_Environmental_Mastery_the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?
# Reversed PWB_Environmental_Mastery_the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?
# Reversing PWB_Personal_Growth_the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?
# Reversed PWB_Personal_Growth_the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?
# Reversing PWB_Positive_Relations_the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?
# Reversed PWB_Positive_Relations_the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?
# Reversing PWB_Self-Acceptance_the_speaker_liked_most_parts_of_their_personality?
# Reversed PWB_Self-Acceptance_the_speaker_liked_most_parts_of_their_personality?

# %%
items_path = 'dataframes/scales_clean.csv'
items = pd.read_csv(items_path)

# Clean and sanitize column names
items['Scale'] = items['Scale'].str.strip().str.replace(r"\s+", "_", regex=True)
items['Dimension'] = items['Dimension'].str.strip().str.replace(r"\s+", "_", regex=True)
items['Items'] = items['Items'].str.strip().str.replace(r"\s+", "_", regex=True)

# Create flattened column names
cols = [f"{scale}_{dimension}_{item}" for scale, dimension, item in zip(
    items['Scale'], items['Dimension'], items['Items']
)]

# %%
#subset df with cols
df_subset = results[cols]
print(df_subset.columns)
# Out:
# Index(['PERMA_Accomplishment_the_speaker_felt_they_were_making_progress_towards_accomplishing_their_goals?',
#        'PERMA_Engagement_the_speaker_became_absorbed_in_what_they_were_doing?',
#        'PERMA_Positive_Emotion_the_speaker_felt_joyful?',
#        'PERMA_Negative_emotion_the_speaker_felt_anxious?',
#        'PERMA_Accomplishment_the_speaker_achieved_the_important_goals_they_set_for_themselves?',
#        'PERMA_Health_the_speaker_perceived_their_health_positively?',
#        'PERMA_Meaning_the_speaker_felt_their_life_was_purposeful_and_meaningful?',
#        'PERMA_Relationships_the_speaker_received_help_and_support_from_others_when_needed?',
#        'PERMA_Meaning_the_speaker_felt_what_they_did_in_life_was_valuable_and_worthwhile?',
#        'PERMA_Engagement_the_speaker_felt_excited_and_interested_in_things?',
#        ...
#        'CIT_Optimism_the_speaker_expected_more_good_things_in_their_life_than_bad?',
#        'CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_in_most_ways_their_life_was_close_to_their_ideal?',
#        'CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_satisfied_with_their_life?',
#        'CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_their_life_is_going_well?',
#        'CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_positive_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_happy_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_good_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_negative_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_experienced_unhappy_feelings_most_of_the_time?',
#        'CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_bad_most_of_the_time?'],
#       dtype='object', length=197)

# %%
print(df_subset.head())
#standardize df_subset
scaler = StandardScaler()
df_subset = pd.DataFrame(scaler.fit_transform(df_subset), columns=df_subset.columns)

#calculate kmo and bartlett's test
kmo_all, kmo_model = calculate_kmo(df_subset)

#determine optimal number of factors
fa = FactorAnalyzer(rotation=None)
fa.fit(df_subset)
eigenvalues, _ = fa.get_eigenvalues()

#fit factor analysis with optimal factors
optimal_factors = sum(eigenvalues > 1) # or based on scree plot
fa = FactorAnalyzer(n_factors=optimal_factors, rotation='varimax')
fa.fit(df_subset)

#project cols onto factors
factor_scores = fa.transform(df_subset)
for i in range(factor_scores.shape[1]):
    results[f'Factor_{i+1}'] = factor_scores[:, i]
# Out:
#    PERMA_Accomplishment_the_speaker_felt_they_were_making_progress_towards_accomplishing_their_goals?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                6.0
# 3                                                6.0
# 4                                                3.0
#
#    PERMA_Engagement_the_speaker_became_absorbed_in_what_they_were_doing?  \
# 0                                                5.0
# 1                                                2.0
# 2                                                4.0
# 3                                                4.0
# 4                                                5.0
#
#    PERMA_Positive_Emotion_the_speaker_felt_joyful?  \
# 0                                              6.0
# 1                                              6.0
# 2                                              5.0
# 3                                              6.0
# 4                                              6.0
#
#    PERMA_Negative_emotion_the_speaker_felt_anxious?  \
# 0                                               2.0
# 1                                               1.0
# 2                                               2.0
# 3                                               3.0
# 4                                               1.0
#
#    PERMA_Accomplishment_the_speaker_achieved_the_important_goals_they_set_for_themselves?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                5.0
# 3                                                6.0
# 4                                                5.0
#
#    PERMA_Health_the_speaker_perceived_their_health_positively?  \
# 0                                                5.0
# 1                                                2.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    PERMA_Meaning_the_speaker_felt_their_life_was_purposeful_and_meaningful?  \
# 0                                                6.0
# 1                                                5.0
# 2                                                4.0
# 3                                                5.0
# 4                                                5.0
#
#    PERMA_Relationships_the_speaker_received_help_and_support_from_others_when_needed?  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 3                                                5.0
# 4                                                1.0
#
#    PERMA_Meaning_the_speaker_felt_what_they_did_in_life_was_valuable_and_worthwhile?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                5.0
# 3                                                5.0
# 4                                                6.0
#
#    PERMA_Engagement_the_speaker_felt_excited_and_interested_in_things?  ...  \
# 0                                                6.0                    ...
# 1                                                6.0                    ...
# 2                                                4.0                    ...
# 3                                                5.0                    ...
# 4                                                6.0                    ...
#
#    CIT_Optimism_the_speaker_expected_more_good_things_in_their_life_than_bad?  \
# 0                                                6.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                6.0
#
#    CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_in_most_ways_their_life_was_close_to_their_ideal?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                5.0
# 3                                                5.0
# 4                                                6.0
#
#    CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_satisfied_with_their_life?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                5.0
# 3                                                5.0
# 4                                                6.0
#
#    CIT_Subjective_Well-Being_-_Life_Satisfaction_the_speaker_felt_their_life_is_going_well?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                5.0
# 3                                                5.0
# 4                                                6.0
#
#    CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_positive_most_of_the_time?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                5.0
# 3                                                6.0
# 4                                                6.0
#
#    CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_happy_most_of_the_time?  \
# 0                                                6.0
# 1                                                4.0
# 2                                                5.0
# 3                                                5.0
# 4                                                6.0
#
#    CIT_Subjective_Well-Being_-_Positive_Feelings_the_speaker_felt_good_most_of_the_time?  \
# 0                                                6.0
# 1                                                6.0
# 2                                                5.0
# 3                                                6.0
# 4                                                6.0
#
#    CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_negative_most_of_the_time?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                2.0
# 4                                                1.0
#
#    CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_experienced_unhappy_feelings_most_of_the_time?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                3.0
# 4                                                1.0
#
#    CIT_Subjective_Well-Being_-_Negative_Feelings_the_speaker_felt_bad_most_of_the_time?
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                2.0
# 4                                                1.0
#
# [5 rows x 197 columns]
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/factor_analyzer/utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/nsusser/Desktop/Github/happyDB/openaivenv/lib/python3.13/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
#save csv
results.to_csv('results 1000 - factors.csv')

# %%
#print top ten
variable_name_mapping = dict(zip(cols, items)) #map cols to variable names
factor_loadings = pd.DataFrame(fa.loadings_, index=items)


for i in range(factor_loadings.shape[1]):
    sorted_loadings = factor_loadings.iloc[:, i].abs().sort_values(ascending=False)
    top_variables = sorted_loadings.head(10).index.tolist()
    print(f'Factor {i+1}: {top_variables}')


# Create an empty list to store the results
factor_loading_results = []

# Iterate through each factor's loadings
for i in range(factor_loadings.shape[1]):
    sorted_loadings = factor_loadings.iloc[:, i].abs().sort_values(ascending=False)
    top_variables = sorted_loadings.head(10).index.tolist()
    top_loadings = sorted_loadings.head(10).values.tolist()
    
    # Append each factor's results to the list
    for var, loading in zip(top_variables, top_loadings):
        factor_loading_results.append({
            'Factor': f'Factor {i+1}',
            'Variable': var,
            'Loading': loading
        })

# Convert the results to a DataFrame
factor_loading_df = pd.DataFrame(factor_loading_results)

# Save to a CSV file
factor_loading_df.to_csv('factor_loadings.csv', index=False)

print("Factor loadings saved to 'factor_loadings.csv'.")
# Out:
# Factor 1: [('WBP', 'Competence', 'the_speaker_was_competent_and_capable_in_important_activities?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_succeeded_when_they_put_their_mind_to_it?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_believed_that_they_are_capable_in_most_things?'), ('WBP', 'Meaning', 'the_speaker_felt_a_sense_of_direction?'), ('WBP', 'Meaning', 'the_speaker_had_a_clear_sense_of_purpose?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_a_sense_of_direction_and_purpose?'), ('CIT', 'Mastery_-_Accomplishment', 'the_speaker_felt_they_fulfilled_their_ambitions?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_skills_a_lot_in_their_everyday_life?'), ('PANAS', 'Positive', 'the_speaker_was_determined?'), ('WBP', 'Clear_Thinking', 'the_speaker_stayed_focused_when_they_needed_to?')]
# Factor 2: [('PERMA', 'Positive_Emotion', 'the_speaker_felt_joyful?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_cheerful?'), ('WBP', 'Optimism', 'the_speaker_felt_very_optimistic_in_the_moment?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_happy?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_cheerful_and_in_good_spirits?'), ('WBP', 'Positive_Emotions', 'the_speaker_considered_themselves_happy?'), ('PERMA', 'Happiness', 'the_speaker_felt_happy_overall?'), ('PERMA', 'Positive_Emotion', 'the_speaker_felt_contented?'), ('CIT', 'Optimism', 'the_speaker_had_a_positive_outlook_on_life?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_satisfied_with_their_life?')]
# Factor 3: [('WBP', 'Positive_Relationships', 'the_speaker_felt_supported_by_people_who_care_about_them?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_appreciated_the_speaker_as_a_person?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?'), ('PERMA', 'Relationships', 'the_speaker_felt_satisfied_with_their_personal_relationships?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_people_with_whom_they_can_discuss_intimate_and_personal_matters?'), ('PERMA', 'Relationships', 'the_speaker_felt_loved?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('PWB', 'Positive_Relations', 'the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('CIT', 'Relationship_-_Trust', 'the_speaker_trusted_people_in_their_society?')]
# Factor 4: [('PWB', 'Environmental_Mastery', 'the_demands_of_everyday_life_affected_the_speaker_negatively?'), ('PWB', 'Environmental_Mastery', 'the_speaker_found_it_difficult_to_arrange_their_life_in_a_satisfying_way?'), ('PWB', 'Self-Acceptance', "the_speaker's_self-attitude_was_less_positive_than_most_people's?"), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_they_did_not_fit_well_with_the_people_and_community_around_them?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('WBP', 'Self-Acceptance', 'the_speaker_admitted_their_shortcomings_without_shame_or_embarrassment?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_experienced_unhappy_feelings_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_disappointed_by_their_achievements_in_life?')]
# Factor 5: [('PERMA', 'Engagement', 'the_speaker_became_absorbed_in_what_they_were_doing?'), ('PERMA', 'Engagement', 'the_speaker_lost_track_of_time_while_doing_something_they_enjoyed?'), ('CIT', 'Engagement', 'the_speaker_was_fully_absorbed_in_the_activities_they_were_doing?'), ('WHO-5', 'Well-Being', "the_speaker's_daily_life_has_been_filled_with_things_that_interest_them?"), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PWB', 'Purpose_in_Life', 'the_speaker_lived_one_day_at_a_time_without_much_thought_for_the_future?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_make_their_own_choices?'), ('WBP', 'Clear_Thinking', 'the_speaker_was_able_to_concentrate_when_necessary?'), ('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_act_on_their_decisions?')]
# Factor 6: [('CIT', 'Relationship_-_Community', 'the_speaker_pitched_in_to_help_when_their_local_community_needed_something_done?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_offered_help_to_others?'), ('CIT', 'Relationship_-_Community', 'the_speaker_looked_for_ways_to_help_their_neighbors_when_they_are_in_need?'), ('WBP', 'Empathy', "the_speaker's_heart_went_out_to_people_who_are_unhappy?"), ('WBP', 'Prosocial_Behavior', 'the_speaker_willingly_gave_their_time_to_others_in_need?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_things_they_did_contributed_to_society?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_would_do_almost_anything_they_could_to_assist_if_a_person_needed_help?'), ('WBP', 'Empathy', "other_people's_misfortunes_disturbed_the_speaker_a_great_deal?"), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_work_they_did_was_important_for_other_people?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?')]
# Factor 7: [('PERMA', 'Health', 'the_speaker_perceived_their_health_positively?'), ('PERMA', 'Health', 'the_speaker_felt_satisfied_with_their_current_physical_health?'), ('PERMA', 'Health', 'the_speaker_perceived_their_health_to_be_better_than_others_of_the_same_age_and_sex?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('WBP', 'Self-Acceptance', 'the_speaker_accepted_who_they_are?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?')]
# Factor 8: [('WBP', 'Vitality', 'the_speaker_felt_energetic?'), ('WBP', 'Vitality', 'the_speaker_felt_full_of_energy?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_active_and_vigorous?'), ('WBP', 'Vitality', 'the_speaker_felt_active_and_vigorous?'), ('CIT', 'Engagement', 'the_speaker_felt_energized_in_most_activities_they_do?'), ('PERMA', 'Engagement', 'the_speaker_felt_excited_and_interested_in_things?'), ('WBP', 'Engagement', 'the_speaker_felt_excited_by_what_they_were_doing?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('PANAS', 'Positive', 'the_speaker_was_excited?'), ('PANAS', 'Positive', 'the_speaker_was_active?')]
# Factor 9: [('WBP', 'Autonomy', 'the_speaker_felt_free_to_make_their_own_choices?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_act_on_their_decisions?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_in_charge_of_the_situation?'), ('PWB', 'Autonomy', "the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?"), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_work_they_did_was_important_for_other_people?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?'), ('PANAS', 'Positive', 'the_speaker_was_proud?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?")]
# Factor 10: [('PANAS', 'Negative', 'the_speaker_was_nervous?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_anxious?'), ('PANAS', 'Negative', 'the_speaker_was_jittery?'), ('PANAS', 'Negative', 'the_speaker_was_scared?'), ('PANAS', 'Negative', 'the_speaker_was_afraid?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('WBP', 'Emotional_Stability', 'the_speaker_was_emotionally_balanced_and_even-tempered?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?')]
# Factor 11: [('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_state_or_province?'), ('CIT', 'Relationship_-_Trust', "people_in_the_speaker's_neighborhood_could_be_trusted?"), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_community?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_mutual_trust_with_their_friends?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('CIT', 'Relationship_-_Community', 'the_speaker_invited_their_neighbors_to_their_home?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?')]
# Factor 12: [('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_found_it_difficult_to_voice_their_opinions_on_controversial_matters?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_felt_learning_new_things_is_important?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_learned_something_new?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_always_learns_something_everyday?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?')]
# Factor 13: [('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('WBP', 'Emotional_Stability', 'the_speaker_maintained_their_composure?'), ('WBP', 'Emotional_Stability', 'the_speaker_was_emotionally_balanced_and_even-tempered?'), ('WBP', 'Emotional_Stability', 'the_speaker_did_not_get_upset_easily?'), ('WBP', 'Clear_Thinking', 'the_speaker’s_ability_to_think_clearly?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Optimism', 'the_speaker_always_feels_optimistic_in_the_moment?'), ('PERMA', 'Accomplishment', 'the_speaker_was_able_to_handle_their_responsibilities?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?')]
# Factor 14: [('PERMA', 'Negative_emotion', 'the_speaker_felt_angry?'), ('PANAS', 'Negative', 'the_speaker_was_hostile?'), ('PANAS', 'Negative', 'the_speaker_was_irritable?'), ('PANAS', 'Negative', 'the_speaker_was_upset?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_experienced_unhappy_feelings_most_of_the_time?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PANAS', 'Negative', 'the_speaker_was_ashamed?'), ('PANAS', 'Negative', 'the_speaker_was_guilty?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?')]
# Factor 15: [('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PANAS', 'Positive', 'the_speaker_was_interested?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('WBP', 'Engagement', 'the_speaker_was_engaged_and_interested_in_the_activity?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('PERMA', 'Negative_emotion', 'the_speaker_felt_sad?'), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?'), ('PANAS', 'Negative', 'the_speaker_was_upset?')]
# Factor 16: [('CIT', 'Mastery_-_Learning', 'the_speaker_learned_something_new?'), ('PWB', 'Personal_Growth', 'the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_felt_learning_new_things_is_important?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_always_learns_something_everyday?'), ('PWB', 'Personal_Growth', 'the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?'), ('PWB', 'Personal_Growth', 'the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?'), ('PANAS', 'Positive', 'the_speaker_was_inspired?'), ('CIT', 'Mastery_-_Accomplishment', 'the_speaker_felt_they_achieved_most_of_their_goals?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('PERMA', 'Accomplishment', 'the_speaker_was_able_to_handle_their_responsibilities?')]
# Factor 17: [('CIT', 'Meaning', 'the_speaker_felt_their_life_has_a_clear_sense_of_purpose?'), ('PERMA', 'Meaning', 'the_speaker_felt_they_had_a_sense_of_direction_in_life?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_they_had_direction_in_life,_unlike_those_who_wander_aimlessly?'), ('PANAS', 'Positive', 'the_speaker_was_inspired?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_a_sense_of_direction_and_purpose?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_mutual_trust_with_their_friends?'), ('CIT', 'Mastery_-_Accomplishment', 'the_speaker_felt_they_were_on_track_to_reach_their_dreams?'), ('WBP', 'Optimism', 'the_speaker_always_feels_optimistic_in_the_moment?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_talents?')]
# Factor 18: [('SWLS', 'LS', 'the_speaker_felt_they_had_gotten_the_important_things_they_wanted_in_life?'), ('SWLS', 'LS', 'the_speaker_felt_their_life_was_close_to_their_ideal?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_in_most_ways_their_life_was_close_to_their_ideal?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('SWLS', 'LS', 'the_speaker_felt_the_conditions_of_their_life_were_excellent?'), ('CIT', 'Meaning', 'the_speaker_felt_they_had_found_a_satisfactory_meaning_in_life?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_pleased_with_how_their_life_had_turned_out?'), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?'), ('PERMA', 'Meaning', 'the_speaker_felt_what_they_did_in_life_was_valuable_and_worthwhile?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_their_life_is_going_well?')]
# Factor 19: [('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('PANAS', 'Positive', 'the_speaker_was_proud?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?'), ('PWB', 'Environmental_Mastery', 'the_demands_of_everyday_life_affected_the_speaker_negatively?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('WBP', 'Clear_Thinking', 'the_speaker’s_ability_to_think_clearly?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?')]
# Factor 20: [('PERMA', 'Relationships', 'the_speaker_received_help_and_support_from_others_when_needed?'), ('WBP', 'Positive_Relationships', 'the_speaker_received_help_and_support_from_others_when_they_needed_it?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?'), ('CIT', 'Engagement', 'the_speaker_felt_excited_when_they_were_working_on_something?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('WBP', 'Empathy', "the_speaker_felt_other's_emotions?"), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PWB', 'Positive_Relations', 'the_speaker_was_seen_as_loving_and_affectionate?'), ('WBP', 'Empathy', "the_speaker_easily_got_caught_up_in_other_people's_feelings?")]
# Factor 21: [('PERMA', 'Lonliness', 'the_speaker_felt_lonely_in_their_daily_life?'), ('CIT', 'Relationship_-_Loneliness', 'the_speaker_felt_lonely?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_lonely_due_to_a_lack_of_close_friends_for_sharing_concerns?'), ('WBP', 'Self-Acceptance', 'the_speaker_admitted_their_shortcomings_without_shame_or_embarrassment?'), ('CIT', 'Relationship_-_Loneliness', 'the_speaker_often_felt_left_out?'), ('PANAS', 'Negative', 'the_speaker_was_ashamed?'), ('PANAS', 'Negative', 'the_speaker_was_guilty?'), ('PWB', 'Positive_Relations', 'the_speaker_had_not_experienced_many_warm_and_trusting_relationships_with_others?'), ('CIT', 'Relationship_-_Loneliness', 'there_was_no_one_the_speaker_felt_close_to?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?")]
# Factor 22: [('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('WBP', 'Competence', 'the_speaker_believes_they_do_most_things_well?'), ('CIT', 'Relationship_-_Respect', 'people_respected_the_speaker?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?'), ('WBP', 'Meaning', 'the_speaker_had_a_clear_sense_of_purpose?'), ('WBP', 'Self-Esteem', 'the_speaker_felt_that_they_have_a_number_of_good_qualities?'), ('SWLS', 'LS', 'the_speaker_felt_they_would_change_almost_nothing_if_they_could_live_life_over?'), ('CIT', 'Relationship_-_Respect', 'people_were_polite_to_the_speaker?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?'), ('WBP', 'Self-Acceptance', 'the_speaker_accepted_who_they_are?')]
# Factor 23: [('CIT', 'Relationship_-_Community', 'the_speaker_invited_their_neighbors_to_their_home?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('CIT', 'Relationship_-_Respect', 'the_speaker_was_treated_with_the_same_amount_of_respect_as_others?'), ('PANAS', 'Negative', 'the_speaker_was_guilty?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('PERMA', 'Accomplishment', 'the_speaker_achieved_the_important_goals_they_set_for_themselves?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?'), ('CIT', 'Optimism', 'the_speaker_felt_optimistic_about_their_future?'), ('PERMA', 'Accomplishment', 'the_speaker_felt_they_were_making_progress_towards_accomplishing_their_goals?'), ('PWB', 'Purpose_in_Life', 'the_speaker_found_their_daily_activities_trivial_and_unimportant?')]
# Factor loadings saved to 'factor_loadings.csv'.

# %%
# Dictionary to store items by factors
factor_items = {}

# Iterate through each factor's loadings
for i in range(factor_loadings.shape[1]):
    sorted_loadings = factor_loadings.iloc[:, i].abs().sort_values(ascending=False)
    top_variables = sorted_loadings.index.tolist()  # Get all variables sorted by absolute loading
    
    # Add variables to the factor_items dictionary
    factor_items[f'Factor {i+1}'] = top_variables

    # Print top 10 variables for the current factor
    top_ten = top_variables[:10]
    print(f'Factor {i+1}: {top_ten}')

# Convert the results to a DataFrame for export (optional)
factor_loading_results = [
    {
        'Factor': factor, 
        'Variables': ', '.join([str(variable) for variable in variables])  # Convert tuples to strings
    }
    for factor, variables in factor_items.items()
]

# Convert to DataFrame and save to CSV
factor_loading_df = pd.DataFrame(factor_loading_results)
factor_loading_df.to_csv('factor_loadings_grouped.csv', index=False)

print("Factor loadings grouped by factor saved to 'factor_loadings_grouped.csv'.")

# Save the factor_items dictionary for visualization (optional)
with open('factor_items.json', 'w') as f:
    import json
    json.dump(factor_items, f)

print("Factor items saved to 'factor_items.json'.")
# Out:
# Factor 1: [('WBP', 'Competence', 'the_speaker_was_competent_and_capable_in_important_activities?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_succeeded_when_they_put_their_mind_to_it?'), ('CIT', 'Mastery_-_Self-Efficacy', 'the_speaker_believed_that_they_are_capable_in_most_things?'), ('WBP', 'Meaning', 'the_speaker_felt_a_sense_of_direction?'), ('WBP', 'Meaning', 'the_speaker_had_a_clear_sense_of_purpose?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_a_sense_of_direction_and_purpose?'), ('CIT', 'Mastery_-_Accomplishment', 'the_speaker_felt_they_fulfilled_their_ambitions?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_skills_a_lot_in_their_everyday_life?'), ('PANAS', 'Positive', 'the_speaker_was_determined?'), ('WBP', 'Clear_Thinking', 'the_speaker_stayed_focused_when_they_needed_to?')]
# Factor 2: [('PERMA', 'Positive_Emotion', 'the_speaker_felt_joyful?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_cheerful?'), ('WBP', 'Optimism', 'the_speaker_felt_very_optimistic_in_the_moment?'), ('WBP', 'Positive_Emotions', 'the_speaker_felt_happy?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_cheerful_and_in_good_spirits?'), ('WBP', 'Positive_Emotions', 'the_speaker_considered_themselves_happy?'), ('PERMA', 'Happiness', 'the_speaker_felt_happy_overall?'), ('PERMA', 'Positive_Emotion', 'the_speaker_felt_contented?'), ('CIT', 'Optimism', 'the_speaker_had_a_positive_outlook_on_life?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_satisfied_with_their_life?')]
# Factor 3: [('WBP', 'Positive_Relationships', 'the_speaker_felt_supported_by_people_who_care_about_them?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_appreciated_the_speaker_as_a_person?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_close_and_secure_relationships?'), ('PERMA', 'Relationships', 'the_speaker_felt_satisfied_with_their_personal_relationships?'), ('WBP', 'Positive_Relationships', 'the_speaker_has_people_with_whom_they_can_discuss_intimate_and_personal_matters?'), ('PERMA', 'Relationships', 'the_speaker_felt_loved?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('PWB', 'Positive_Relations', 'the_speaker_enjoyed_personal_and_mutual_conversations_with_family_members_and_friends?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('CIT', 'Relationship_-_Trust', 'the_speaker_trusted_people_in_their_society?')]
# Factor 4: [('PWB', 'Environmental_Mastery', 'the_demands_of_everyday_life_affected_the_speaker_negatively?'), ('PWB', 'Environmental_Mastery', 'the_speaker_found_it_difficult_to_arrange_their_life_in_a_satisfying_way?'), ('PWB', 'Self-Acceptance', "the_speaker's_self-attitude_was_less_positive_than_most_people's?"), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_they_did_not_fit_well_with_the_people_and_community_around_them?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('WBP', 'Self-Acceptance', 'the_speaker_admitted_their_shortcomings_without_shame_or_embarrassment?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_experienced_unhappy_feelings_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_disappointed_by_their_achievements_in_life?')]
# Factor 5: [('PERMA', 'Engagement', 'the_speaker_became_absorbed_in_what_they_were_doing?'), ('PERMA', 'Engagement', 'the_speaker_lost_track_of_time_while_doing_something_they_enjoyed?'), ('CIT', 'Engagement', 'the_speaker_was_fully_absorbed_in_the_activities_they_were_doing?'), ('WHO-5', 'Well-Being', "the_speaker's_daily_life_has_been_filled_with_things_that_interest_them?"), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PWB', 'Purpose_in_Life', 'the_speaker_lived_one_day_at_a_time_without_much_thought_for_the_future?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_make_their_own_choices?'), ('WBP', 'Clear_Thinking', 'the_speaker_was_able_to_concentrate_when_necessary?'), ('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_act_on_their_decisions?')]
# Factor 6: [('CIT', 'Relationship_-_Community', 'the_speaker_pitched_in_to_help_when_their_local_community_needed_something_done?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_offered_help_to_others?'), ('CIT', 'Relationship_-_Community', 'the_speaker_looked_for_ways_to_help_their_neighbors_when_they_are_in_need?'), ('WBP', 'Empathy', "the_speaker's_heart_went_out_to_people_who_are_unhappy?"), ('WBP', 'Prosocial_Behavior', 'the_speaker_willingly_gave_their_time_to_others_in_need?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_things_they_did_contributed_to_society?'), ('WBP', 'Prosocial_Behavior', 'the_speaker_would_do_almost_anything_they_could_to_assist_if_a_person_needed_help?'), ('WBP', 'Empathy', "other_people's_misfortunes_disturbed_the_speaker_a_great_deal?"), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_work_they_did_was_important_for_other_people?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?')]
# Factor 7: [('PERMA', 'Health', 'the_speaker_perceived_their_health_positively?'), ('PERMA', 'Health', 'the_speaker_felt_satisfied_with_their_current_physical_health?'), ('PERMA', 'Health', 'the_speaker_perceived_their_health_to_be_better_than_others_of_the_same_age_and_sex?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('WBP', 'Self-Acceptance', 'the_speaker_accepted_who_they_are?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?')]
# Factor 8: [('WBP', 'Vitality', 'the_speaker_felt_energetic?'), ('WBP', 'Vitality', 'the_speaker_felt_full_of_energy?'), ('WHO-5', 'Well-Being', 'the_speaker_felt_active_and_vigorous?'), ('WBP', 'Vitality', 'the_speaker_felt_active_and_vigorous?'), ('CIT', 'Engagement', 'the_speaker_felt_energized_in_most_activities_they_do?'), ('PERMA', 'Engagement', 'the_speaker_felt_excited_and_interested_in_things?'), ('WBP', 'Engagement', 'the_speaker_felt_excited_by_what_they_were_doing?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('PANAS', 'Positive', 'the_speaker_was_excited?'), ('PANAS', 'Positive', 'the_speaker_was_active?')]
# Factor 9: [('WBP', 'Autonomy', 'the_speaker_felt_free_to_make_their_own_choices?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_decide_for_themselves_how_to_live_their_life?'), ('WBP', 'Autonomy', 'the_speaker_felt_free_to_act_on_their_decisions?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_in_charge_of_the_situation?'), ('PWB', 'Autonomy', "the_speaker's_decisions_were_not_influenced_by_what_everyone_else_was_doing?"), ('PANAS', 'Positive', 'the_speaker_was_active?'), ('CIT', 'Mastery_-_Self-Worth', 'the_speaker_felt_the_work_they_did_was_important_for_other_people?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?'), ('PANAS', 'Positive', 'the_speaker_was_proud?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?")]
# Factor 10: [('PANAS', 'Negative', 'the_speaker_was_nervous?'), ('PERMA', 'Negative_emotion', 'the_speaker_felt_anxious?'), ('PANAS', 'Negative', 'the_speaker_was_jittery?'), ('PANAS', 'Negative', 'the_speaker_was_scared?'), ('PANAS', 'Negative', 'the_speaker_was_afraid?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?"), ('WBP', 'Emotional_Stability', 'the_speaker_was_emotionally_balanced_and_even-tempered?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?')]
# Factor 11: [('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_state_or_province?'), ('CIT', 'Relationship_-_Trust', "people_in_the_speaker's_neighborhood_could_be_trusted?"), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_community?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_mutual_trust_with_their_friends?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('CIT', 'Relationship_-_Community', 'the_speaker_invited_their_neighbors_to_their_home?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?')]
# Factor 12: [('PWB', 'Autonomy', 'the_speaker_was_not_afraid_to_voice_their_opinions,_even_when_they_were_in_opposition_to_others?'), ('PWB', 'Autonomy', 'the_speaker_was_influenced_by_people_with_strong_opinions?'), ('PWB', 'Autonomy', 'the_speaker_had_confidence_in_their_opinions,_even_if_contrary_to_the_general_consensus?'), ('PWB', 'Autonomy', 'the_speaker_found_it_difficult_to_voice_their_opinions_on_controversial_matters?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_felt_learning_new_things_is_important?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_learned_something_new?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_always_learns_something_everyday?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('CIT', 'Relationship_-_Belonging', 'the_speaker_felt_a_sense_of_belonging_in_their_country?')]
# Factor 13: [('WHO-5', 'Well-Being', 'the_speaker_felt_calm_and_relaxed?'), ('WBP', 'Emotional_Stability', 'the_speaker_maintained_their_composure?'), ('WBP', 'Emotional_Stability', 'the_speaker_was_emotionally_balanced_and_even-tempered?'), ('WBP', 'Emotional_Stability', 'the_speaker_did_not_get_upset_easily?'), ('WBP', 'Clear_Thinking', 'the_speaker’s_ability_to_think_clearly?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('WHO-5', 'Well-Being', 'the_speaker_woke_up_feeling_fresh_and_rested?'), ('WBP', 'Optimism', 'the_speaker_always_feels_optimistic_in_the_moment?'), ('PERMA', 'Accomplishment', 'the_speaker_was_able_to_handle_their_responsibilities?'), ('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?')]
# Factor 14: [('PERMA', 'Negative_emotion', 'the_speaker_felt_angry?'), ('PANAS', 'Negative', 'the_speaker_was_hostile?'), ('PANAS', 'Negative', 'the_speaker_was_irritable?'), ('PANAS', 'Negative', 'the_speaker_was_upset?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_negative_most_of_the_time?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_experienced_unhappy_feelings_most_of_the_time?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PANAS', 'Negative', 'the_speaker_was_ashamed?'), ('PANAS', 'Negative', 'the_speaker_was_guilty?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?')]
# Factor 15: [('PANAS', 'Positive', 'the_speaker_was_attentive?'), ('WBP', 'Engagement', 'the_speaker_was_really_interested_in_what_they_were_doing?'), ('PANAS', 'Positive', 'the_speaker_was_interested?'), ('PANAS', 'Positive', 'the_speaker_was_alert?'), ('WBP', 'Engagement', 'the_speaker_was_engaged_and_interested_in_the_activity?'), ('CIT', 'Autonomy_-_Control', 'other_people_decided_what_the_speaker_could_and_could_not_do?'), ('CIT', 'Autonomy_-_Control', "other_people_decided_most_of_the_speaker's_life_decisions?"), ('PERMA', 'Negative_emotion', 'the_speaker_felt_sad?'), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?'), ('PANAS', 'Negative', 'the_speaker_was_upset?')]
# Factor 16: [('CIT', 'Mastery_-_Learning', 'the_speaker_learned_something_new?'), ('PWB', 'Personal_Growth', 'the_speaker_valued_new_experiences_that_challenge_their_thoughts_about_themselves_and_the_world?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_felt_learning_new_things_is_important?'), ('CIT', 'Mastery_-_Learning', 'the_speaker_always_learns_something_everyday?'), ('PWB', 'Personal_Growth', 'the_speaker_was_continuously_in_the_process_of_learning,_changing,_and_growing?'), ('PWB', 'Personal_Growth', 'the_speaker_felt_they_had_developed_significantly_as_a_person_over_time?'), ('PANAS', 'Positive', 'the_speaker_was_inspired?'), ('CIT', 'Mastery_-_Accomplishment', 'the_speaker_felt_they_achieved_most_of_their_goals?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('PERMA', 'Accomplishment', 'the_speaker_was_able_to_handle_their_responsibilities?')]
# Factor 17: [('CIT', 'Meaning', 'the_speaker_felt_their_life_has_a_clear_sense_of_purpose?'), ('PERMA', 'Meaning', 'the_speaker_felt_they_had_a_sense_of_direction_in_life?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_they_had_direction_in_life,_unlike_those_who_wander_aimlessly?'), ('PANAS', 'Positive', 'the_speaker_was_inspired?'), ('PWB', 'Purpose_in_Life', 'the_speaker_felt_a_sense_of_direction_and_purpose?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_mutual_trust_with_their_friends?'), ('CIT', 'Mastery_-_Accomplishment', 'the_speaker_felt_they_were_on_track_to_reach_their_dreams?'), ('WBP', 'Optimism', 'the_speaker_always_feels_optimistic_in_the_moment?'), ('CIT', 'Mastery_-_Skills', 'the_speaker_used_their_talents?')]
# Factor 18: [('SWLS', 'LS', 'the_speaker_felt_they_had_gotten_the_important_things_they_wanted_in_life?'), ('SWLS', 'LS', 'the_speaker_felt_their_life_was_close_to_their_ideal?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_in_most_ways_their_life_was_close_to_their_ideal?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('SWLS', 'LS', 'the_speaker_felt_the_conditions_of_their_life_were_excellent?'), ('CIT', 'Meaning', 'the_speaker_felt_they_had_found_a_satisfactory_meaning_in_life?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_pleased_with_how_their_life_had_turned_out?'), ('CIT', 'Meaning', 'the_speaker_knew_what_gives_meaning_to_their_life?'), ('PERMA', 'Meaning', 'the_speaker_felt_what_they_did_in_life_was_valuable_and_worthwhile?'), ('CIT', 'Subjective_Well-Being_-_Life_Satisfaction', 'the_speaker_felt_their_life_is_going_well?')]
# Factor 19: [('WBP', 'Resilience', 'the_speaker_recovered_quickly_from_a_stressful_event?'), ('WBP', 'Resilience', 'the_speaker_bounced_back_quickly_after_hard_times?'), ('PANAS', 'Positive', 'the_speaker_was_proud?'), ('CIT', 'Subjective_Well-Being_-_Negative_Feelings', 'the_speaker_felt_bad_most_of_the_time?'), ('PWB', 'Environmental_Mastery', 'the_demands_of_everyday_life_affected_the_speaker_negatively?'), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('WBP', 'Clear_Thinking', 'the_speaker’s_ability_to_think_clearly?'), ('WBP', 'Resilience', 'the_speaker_got_over_and_recovered_from_significant_life_difficulties?'), ('PWB', 'Autonomy', 'the_speaker_worried_about_what_others_thought_of_them?')]
# Factor 20: [('PERMA', 'Relationships', 'the_speaker_received_help_and_support_from_others_when_needed?'), ('WBP', 'Positive_Relationships', 'the_speaker_received_help_and_support_from_others_when_they_needed_it?'), ('CIT', 'Relationship_-_Support', 'there_are_people_the_speaker_depended_on_to_help_them?'), ('PWB', 'Positive_Relations', 'the_speaker_would_be_described_as_a_giving_person,_willing_to_share_their_time_with_others?'), ('CIT', 'Engagement', 'the_speaker_felt_excited_when_they_were_working_on_something?'), ('CIT', 'Relationship_-_Support', 'there_are_people_who_gave_the_speaker_support_and_encouragement?'), ('WBP', 'Empathy', "the_speaker_felt_other's_emotions?"), ('PANAS', 'Negative', 'the_speaker_was_distressed?'), ('PWB', 'Positive_Relations', 'the_speaker_was_seen_as_loving_and_affectionate?'), ('WBP', 'Empathy', "the_speaker_easily_got_caught_up_in_other_people's_feelings?")]
# Factor 21: [('PERMA', 'Lonliness', 'the_speaker_felt_lonely_in_their_daily_life?'), ('CIT', 'Relationship_-_Loneliness', 'the_speaker_felt_lonely?'), ('PWB', 'Positive_Relations', 'the_speaker_felt_lonely_due_to_a_lack_of_close_friends_for_sharing_concerns?'), ('WBP', 'Self-Acceptance', 'the_speaker_admitted_their_shortcomings_without_shame_or_embarrassment?'), ('CIT', 'Relationship_-_Loneliness', 'the_speaker_often_felt_left_out?'), ('PANAS', 'Negative', 'the_speaker_was_ashamed?'), ('PANAS', 'Negative', 'the_speaker_was_guilty?'), ('PWB', 'Positive_Relations', 'the_speaker_had_not_experienced_many_warm_and_trusting_relationships_with_others?'), ('CIT', 'Relationship_-_Loneliness', 'there_was_no_one_the_speaker_felt_close_to?'), ('PWB', 'Autonomy', "the_speaker_judged_themselves_by_their_own_values_rather_than_by_others'_values?")]
# Factor 22: [('PWB', 'Self-Acceptance', 'the_speaker_felt_good_about_themselves_when_comparing_to_friends_and_acquaintances?'), ('WBP', 'Competence', 'the_speaker_believes_they_do_most_things_well?'), ('CIT', 'Relationship_-_Respect', 'people_respected_the_speaker?'), ('PWB', 'Purpose_in_Life', 'the_speaker_enjoyed_making_plans_for_the_future_and_working_to_make_them_a_reality?'), ('WBP', 'Meaning', 'the_speaker_had_a_clear_sense_of_purpose?'), ('WBP', 'Self-Esteem', 'the_speaker_felt_that_they_have_a_number_of_good_qualities?'), ('SWLS', 'LS', 'the_speaker_felt_they_would_change_almost_nothing_if_they_could_live_life_over?'), ('CIT', 'Relationship_-_Respect', 'people_were_polite_to_the_speaker?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?'), ('WBP', 'Self-Acceptance', 'the_speaker_accepted_who_they_are?')]
# Factor 23: [('CIT', 'Relationship_-_Community', 'the_speaker_invited_their_neighbors_to_their_home?'), ('PWB', 'Environmental_Mastery', 'the_speaker_had_built_a_living_environment_and_lifestyle_they_liked?'), ('CIT', 'Relationship_-_Respect', 'the_speaker_was_treated_with_the_same_amount_of_respect_as_others?'), ('PANAS', 'Negative', 'the_speaker_was_guilty?'), ('PWB', 'Environmental_Mastery', 'the_speaker_felt_that_they_were_good_at_managing_the_responsibilities_of_daily_life?'), ('PERMA', 'Accomplishment', 'the_speaker_achieved_the_important_goals_they_set_for_themselves?'), ('CIT', 'Relationship_-_Trust', 'most_people_the_speaker_met_were_honest?'), ('CIT', 'Optimism', 'the_speaker_felt_optimistic_about_their_future?'), ('PERMA', 'Accomplishment', 'the_speaker_felt_they_were_making_progress_towards_accomplishing_their_goals?'), ('PWB', 'Purpose_in_Life', 'the_speaker_found_their_daily_activities_trivial_and_unimportant?')]
# Factor loadings grouped by factor saved to 'factor_loadings_grouped.csv'.
# Factor items saved to 'factor_items.json'.
